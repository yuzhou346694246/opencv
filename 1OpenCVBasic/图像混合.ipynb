# %%
import cv2
import numpy as np

# %%
logo = cv2.imread('opencv-logo.png')
robot = cv2.imread('robot.jpg')

# %%
logo.shape[:2]
# Out:
# (739, 600)

# %%
robot.shape[:2]
# Out:
# (185, 450)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import imageutils as util

# %%
def imshow(opencv_img, engine='matplotlib'):
    if engine == 'matplotlib':
        img = cv2.cvtColor(opencv_img, cv2.COLOR_BGR2RGB)
        plt.imshow(img)
        plt.xticks([]),plt.yticks([])
        plt.show()

    if engine == 'opencv':
        cv2.imshow(engine,opencv_img)
        cv2.waitKey(0)
        cv2.destroyAllWindows()

# %%
imshow(logo, engine='opencv')

# %%
imshow(robot)
